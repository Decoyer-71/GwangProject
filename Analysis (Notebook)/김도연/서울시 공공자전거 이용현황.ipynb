# %%
api='5275715a616b6d6432376e4a55534b'
import requests

url = f'http://openapi.seoul.go.kr:8088/{api}/json/tbCycleUseStatus/1/1000/202001'

response = requests.get(url)

# %%
json= requests.get(url).json()

# %%
json['useStatus']['row']
# Out:
# [{'STA_LOC': '양천구',
#   'RENT_NM': '729. 서부식자재마트 건너편',
#   'STAT_DATA': '2023-04-04',
#   'RENT_CNT': '63',
#   'RTN_CNT': '53',
#   'START_INDEX': 0,
#   'END_INDEX': 0},
#  {'STA_LOC': '양천구',
#   'RENT_NM': '731. 서울시 도로환경관리센터',
#   'STAT_DATA': '2023-04-04',
#   'RENT_CNT': '120',
#   'RTN_CNT': '119',
#   'START_INDEX': 0,
#   'END_INDEX': 0},
#  {'STA_LOC': '양천구',
#   'RENT_NM': '732. 신월중학교',
#   'STAT_DATA': '2023-04-04',
#   'RENT_CNT': '34',
#   'RTN_CNT': '37',
#   'START_INDEX': 0,
#   'END_INDEX': 0},
#  {'STA_LOC': '양천구',
#   'RENT_NM': '733. 신정이펜하우스314동',
#   'STAT_DATA': '2023-04-04',
#   'RENT_CNT': '35',
#   'RTN_CNT': '13',
#   'START_INDEX': 0,
#   'END_INDEX': 0},
#  {'STA_LOC': '양천구',
#   'RENT_NM': '734. 신트리공원 입구',
#   'STAT_DATA': '2023-04-04',
#   'RENT_CNT': '127',
#   'RTN_CNT': '94',
#   'START_INDEX': 0,
#   'END_INDEX': 0},
#  {'STA_LOC': '양천구',
#   'RENT_NM': '735. 영도초등학교',
#   'STAT_DATA': '2023-04-04',
#   'RENT_CNT': '91',
#   'RTN_CNT': '80',
# ...

# %%
import pandas as pd

# %%
df= pd.read_csv('C:\\Users\\acorn\\Downloads\\서울특별시 공공자전거 이용정보(월별)_2020년\\서울특별시 공공자전거 이용정보(월별)_20.01.csv')

# %%
gr= df.groupby('대여소명').sum()
gr
# Out:
#                             대여소번호  이용건수     이동거리   이용시간
# 대여소명
# 1001. 광진교 남단 사거리(디지털프라자앞)   45045   717  3985410  13209
# 1002. 해공공원(천호동)             41082   569  2784010  10729
# 1003. 해공도서관앞                40120   473  2309120   9083
# 1004. 삼성광나루아파트 버스정류장        41164   428  1847780  11652
# 1006. 롯데캐슬 115동앞            37222   461  1749890  11194
# ...                           ...   ...      ...    ...
# 9997.강남센터                    9997     4        0     26
# 9998. 영남주차장 정비센터             9998     4    20690    104
# 99999. 영남단말기정비             199998    20   141300    873
# 상암센터 정비실                       10     3   196100     97
# 중랑센터                            9     7    20720    143
#
# [1540 rows x 4 columns]

# %%
gu= pd.read_csv('../../Data/공공자전거 대여소 정보(21.01.31 기준).csv', header=[2])
gu
# Out:
#       Unnamed: 0         Unnamed: 1  자치구                  상세주소         위도  \
# 0            NaN                NaN  NaN                   NaN        NaN
# 1            NaN                NaN  NaN                   NaN        NaN
# 2          301.0        경복궁역 7번출구 앞  종로구   서울특별시 종로구 사직로 지하130  37.575794
# 3          302.0        경복궁역 4번출구 뒤  종로구   서울특별시 종로구 사직로 지하130  37.575947
# 4          303.0        광화문역 1번출구 앞  종로구  서울특별시 종로구 세종대로 지하189  37.571770
# ...          ...                ...  ...                   ...        ...
# 2154      1089.0  고덕 래미안힐스테이트(201동)  강동구               고덕동 675  37.560600
# 2155      1090.0        상일동역 2번출구 앞  강동구               고덕로 333  37.556789
# 2156         NaN                NaN  NaN                   NaN        NaN
# 2157         NaN                NaN  NaN                   NaN        NaN
# 2158         NaN                NaN  NaN                   NaN        NaN
#
#               경도  Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# ...

# %%
# ?pd.read_csv
