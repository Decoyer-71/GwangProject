# %%
import pandas as pd
import numpy as np

# %%
area = pd.read_csv("../../Data/상관분석/인구밀도2020.csv")
area
# Out:
#      동별(1)  동별(2)  동별(3)     2020  2020.1      2020.2
# 0    동별(1)  동별(2)  동별(3)   인구 (명)  면적 (㎢)  인구밀도 (명/㎢)
# 1       합계     소계     소계  9911088  605.23       16376
# 2       합계    종로구     소계   158996   23.91        6649
# 3       합계    종로구    사직동     9806    1.23        7972
# 4       합계    종로구    삼청동     2909    1.49        1952
# ..     ...    ...    ...      ...     ...         ...
# 447     합계    강동구   둔촌1동      262    0.92         285
# 448     합계    강동구   둔촌2동    26413    0.98       26952
# 449     합계    강동구   암사1동    35728    1.02       35027
# 450     합계    강동구   천호2동    35251    1.57       22453
# 451     합계    강동구     길동    46868    2.17       21598
#
# [452 rows x 6 columns]
