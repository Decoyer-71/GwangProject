# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.font_manager as fm
font_name=fm.FontProperties(fname="C:\\Windows\\Fonts\\malgun.ttf ").get_name()
plt.rc("font", family=font_name)

import matplotlib as mlp
mlp.rcParams["axes.unicode_minus"]=False

# %%
house = pd.read_csv("C:\kee\Mid\주택종류별+주택-+읍면동(연도+끝자리+0,5),+시군구(그+외+연도)_20230405113432.csv")
house.shape
# Out:
# (28, 6)

# %%
house2 = house1.drop("동별(1)", axis=1)
house3 = house2.drop(0)
house3
# Out:
#     동별(2)   2020  2020.2 2020.3
# 1   동별(2)   단독주택     아파트   연립주택
# 2   동별(2)     소계      소계     소계
# 3     종로구  12259   15688   5460
# 4      중구   5967   26102   1944
# 5     용산구  14064   37676   3969
# 6     성동구  10525   67584   1990
# 7     광진구  15332   32135   4054
# 8    동대문구  17120   65033   3274
# 9     중랑구  18560   55499   4466
# 10    성북구  22520   79206   6262
# 11    강북구  17557   34733   4789
# 12    도봉구   8634   65032   4144
# 13    노원구   6619  163502   3448
# 14    은평구  14937   59438   5830
# 15   서대문구  12600   54132   5461
# 16    마포구  11618   70307   3142
# 17    양천구   7698   90788   4042
# 18    강서구  10260  113767   4794
# 19    구로구  11474   83459   7388
# 20    금천구   8807   31689   3914
# 21   영등포구  14276   74957   1487
# 22    동작구  14522   61606   5289
# 23    관악구  21249   55417   6218
# 24    서초구   5481   94499   5356
# 25    강남구   6968  126023   5827
# 26    송파구   8072  127239   4900
# 27    강동구   9956   87159   3114
