# %%
# pip install geopandas
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
seoul_file = "C:\\YOONJINSEOK\\Python work\\analysis\\data\\LSMD_ADM_SECT_UMD_서울\\LSMD_ADM_SECT_UMD_11.shp"

# %%
seoul = gpd.read_file(seoul_file, encoding = "euc-kr")
seoul
# Out:
#        EMD_CD EMD_NM  SGG_OID COL_ADM_SE   GID  \
# 0    11110154    장사동     4315      11110  3037
# 1    11110153    돈의동     4314      11110  3038
# 2    11290134    길음동     4532      11290  2820
# 3    11290133    정릉동     4531      11290  2821
# 4    11290132  보문동3가     4530      11290  2822
# ..        ...    ...      ...        ...   ...
# 462  11680110   압구정동     1049      11680  2652
# 463  11680108    논현동     1183      11680  2653
# 464  11680107    신사동     1050      11680  2654
# 465  11680106    대치동     1215      11680  2655
# 466  11680105    삼성동     1184      11680  2656
#
#                                               geometry
# 0    POLYGON ((955438.037 1952426.894, 955438.325 1...
# 1    POLYGON ((955054.604 1952786.670, 955055.964 1...
# 2    POLYGON ((957364.694 1957374.485, 957376.240 1...
# 3    POLYGON ((957598.059 1956308.659, 957583.162 1...
# 4    POLYGON ((957323.502 1954285.821, 957323.592 1...
# ..                                                 ...
# ...

# %%
seoul[seoul["EMD_NM"] == "자양동"]
# Out:
#        EMD_CD EMD_NM  SGG_OID COL_ADM_SE   GID  \
# 160  11215105    자양동     4480      11215  2872
#
#                                               geometry
# 160  POLYGON ((962325.558 1948937.413, 962383.020 1...

# %%
seoul = seoul.to_crs(epsg = 4326)
seoul
# Out:
#        EMD_CD EMD_NM  SGG_OID COL_ADM_SE   GID  \
# 0    11110154    장사동     4315      11110  3037
# 1    11110153    돈의동     4314      11110  3038
# 2    11290134    길음동     4532      11290  2820
# 3    11290133    정릉동     4531      11290  2821
# 4    11290132  보문동3가     4530      11290  2822
# ..        ...    ...      ...        ...   ...
# 462  11680110   압구정동     1049      11680  2652
# 463  11680108    논현동     1183      11680  2653
# 464  11680107    신사동     1050      11680  2654
# 465  11680106    대치동     1215      11680  2655
# 466  11680105    삼성동     1184      11680  2656
#
#                                               geometry
# 0    POLYGON ((126.99538 37.57013, 126.99538 37.570...
# 1    POLYGON ((126.99101 37.57336, 126.99103 37.573...
# 2    POLYGON ((127.01691 37.61482, 127.01704 37.614...
# 3    POLYGON ((127.01961 37.60522, 127.01944 37.605...
# 4    POLYGON ((127.01662 37.58698, 127.01662 37.586...
# ..                                                 ...
# ...

# %%
seoul[seoul["EMD_NM"] == "구의동"].geometry
# Out:
# 162    POLYGON ((127.07955 37.54383, 127.07966 37.543...
# Name: geometry, dtype: geometry

# %%
seoul.to_csv("/data/seoul_bubguu.csv", encoding = "utf-8", index = False)

# %%
data = pd.read_csv("/data/seoul_bubguu.csv", encoding = "utf-8")
data[data["EMD_NM"] == "자양동"]
# Out:
#        EMD_CD EMD_NM  SGG_OID  COL_ADM_SE   GID  \
# 160  11215105    자양동     4480       11215  2872
#
#                                               geometry
# 160  POLYGON ((127.07354985801302 37.53898996012444...

# %%
a = data[data["EMD_NM"] == "군자동"]["geometry"]
a
# Out:
# 158    POLYGON ((127.07448984324357 37.54707152433555...
# Name: geometry, dtype: object

# %%
b = str(a.values)

# %%
import re
dong_list = re.findall("(\d+)", b)
dong_list
# Out:
# ['127',
#  '07448984324357',
#  '37',
#  '54707152433555',
#  '127',
#  '0744866983226',
#  '37',
#  '54706085854121',
#  '127',
#  '07413710235059',
#  '37',
#  '54716555299875',
#  '127',
#  '07415691715518',
#  '37',
#  '54721272572832',
#  '127',
#  '07423131075403',
#  '37',
#  '5473897878077',
#  '127',
#  '07397176715634',
#  '37',
#  '547460675152905',
#  '127',
#  '07396088400662',
#  '37',
#  '54746364609112',
#  '127',
#  '07389239948279',
#  '37',
#  '5473116007509',
#  '127',
#  '07388332722238',
#  '37',
#  '54729147816464',
#  '127',
#  '07383761435364',
#  '37',
#  '54718999147547',
#  '127',
#  '07377964724185',
#  '37',
#  '54720660520164',
#  '127',
#  '07376637740417',
#  '37',
#  '547210568672895',
#  '127',
#  '0736946772502',
#  '37',
#  '547231966012625',
#  '127',
#  '07350386505975',
#  '37',
#  '54728892602621',
#  '127',
#  '07340595307402',
#  '37',
#  '5473181507606',
#  '127',
#  '07323786467505',
#  '37',
#  '54736503243525',
#  '127',
# ...

# %%
s1 = []
s2 = []
for i in range(len(dong_list)):
    if i % 2 == 0:
        s1.append(dong_list[i])
    elif i % 2 == 1:
        s2.append(dong_list[i])
print(s1)
print(s2)
# Out:
# ['127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '37', '127', '3
# ...

# %%
ssibal1 = []
for i in range(len(s1)):
    for j in range(len(s2)):
        if i == j:
            ssibal1.append(s1[i] + "." + s2[j])
print(ssibal1)
# Out:
# ['127.07448984324357', '37.54707152433555', '127.0744866983226', '37.54706085854121', '127.07413710235059', '37.54716555299875', '127.07415691715518', '37.54721272572832', '127.07423131075403', '37.5473897878077', '127.07397176715634', '37.547460675152905', '127.07396088400662', '37.54746364609112', '127.07389239948279', '37.5473116007509', '127.07388332722238', '37.54729147816464', '127.07383761435364', '37.54718999147547', '127.07377964724185', '37.54720660520164', '127.07376637740417', '37.547210568672895', '127.0736946772502', '37.547231966012625', '127.07350386505975', '37.54728892602621', '127.07340595307402', '37.5473181507606', '127.07323786467505', '37.54736503243525', '127.07308913260725', '37.54740649619274', '127.07202983881294', '37.54771820970603', '127.07168433028968', '37.54778405271942', '127.07166174649049', '37.54778736376413', '127.0712439687366', '37.54784889660594', '127.07115485257539', '37.54785898623364', '127.07111850515892', '37.54787102688527', '127.070953
# ...

# %%
ssibal2 = []
try : 
    for i in range(len(ssibal1)):
        ssibal2.append([ssibal1[2*i] +", "+ ssibal1[2*i+1]])
except : None
print(ssibal2)
# Out:
# [['127.07448984324357, 37.54707152433555'], ['127.0744866983226, 37.54706085854121'], ['127.07413710235059, 37.54716555299875'], ['127.07415691715518, 37.54721272572832'], ['127.07423131075403, 37.5473897878077'], ['127.07397176715634, 37.547460675152905'], ['127.07396088400662, 37.54746364609112'], ['127.07389239948279, 37.5473116007509'], ['127.07388332722238, 37.54729147816464'], ['127.07383761435364, 37.54718999147547'], ['127.07377964724185, 37.54720660520164'], ['127.07376637740417, 37.547210568672895'], ['127.0736946772502, 37.547231966012625'], ['127.07350386505975, 37.54728892602621'], ['127.07340595307402, 37.5473181507606'], ['127.07323786467505, 37.54736503243525'], ['127.07308913260725, 37.54740649619274'], ['127.07202983881294, 37.54771820970603'], ['127.07168433028968, 37.54778405271942'], ['127.07166174649049, 37.54778736376413'], ['127.0712439687366, 37.54784889660594'], ['127.07115485257539, 37.54785898623364'], ['127.07111850515892, 37.54787102688527'], ['127.07095
# ...

# %%
import re
ssibal3 = []
for i in ssibal2:
    ssibal3.append(re.sub("'", "", str(i)))

# %%
for i in ssibal3:
    print(i+",")
# Out:
# [127.07448984324357, 37.54707152433555],
# [127.0744866983226, 37.54706085854121],
# [127.07413710235059, 37.54716555299875],
# [127.07415691715518, 37.54721272572832],
# [127.07423131075403, 37.5473897878077],
# [127.07397176715634, 37.547460675152905],
# [127.07396088400662, 37.54746364609112],
# [127.07389239948279, 37.5473116007509],
# [127.07388332722238, 37.54729147816464],
# [127.07383761435364, 37.54718999147547],
# [127.07377964724185, 37.54720660520164],
# [127.07376637740417, 37.547210568672895],
# [127.0736946772502, 37.547231966012625],
# [127.07350386505975, 37.54728892602621],
# [127.07340595307402, 37.5473181507606],
# [127.07323786467505, 37.54736503243525],
# [127.07308913260725, 37.54740649619274],
# [127.07202983881294, 37.54771820970603],
# [127.07168433028968, 37.54778405271942],
# [127.07166174649049, 37.54778736376413],
# [127.0712439687366, 37.54784889660594],
# [127.07115485257539, 37.54785898623364],
# [127.07111850515892, 37.54787102688527],
# ...

# %%
# ?print
