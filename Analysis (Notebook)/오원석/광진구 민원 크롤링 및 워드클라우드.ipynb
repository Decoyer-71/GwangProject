# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver_win32\\chromedriver')
url ='https://gwangjin.eminwon.seoul.kr/emwp/gov/mogaha/ntis/web/emwp/cns/action/EmwpCnslWebAction.do?method=selectCnslWebPage&menu_id=EMWPCnslWebInqL&jndinm=EmwpCnslWebEJB&methodnm=selectCnslWebPage&context=NTIS'

try:
    driver.get(url)
    for i in range(1, 11):
        title = driver.find_elements(By.CLASS_NAME, 'td-list')
        for j in title:
            print(j.text)
        
        if i < 10:
            page = driver.find_element(By.LINK_TEXT, str(i+1))
            page.click()
        time.sleep(2)
except Exception as e:
    print(e)
finally:
    driver.close()
    driver.quit()
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_10076\1862303689.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver_win32\\chromedriver')
# 구의1동 길거리 청결
# 동일로 보수공사로 차량이 시멘트물 피해를 입었습니다
# 가로등이 며칠째 안들어옵니다.. 길이 많이 어둡네요...
# 안녕하세요. 준공관련 빠른 승인 요청합니다.
# 안녕하세요? 군자역 인근 흡연피해 민원 관련 글을 적습니다.
# 누후 경계석 교체 민원
# 소음이 너무 심합니다.
# 좀 조용히 쉬고싶어요
# 코로나 구호물품 지급의 건
# 중곡4동 고물상 민원
# 자양동 sc제일은행 사거리 벤치 이동 요청
# 쓰레기 무단투기 cctv확인후 과태료 및 투기범 잡아주세요.
# 안녕하세요. 집앞 쓰레기 및 오물 민원 드립니다
# 광진구 민방위교육훈련 센터를 칭찬합니다.
# 천호대로 140번길이 우범지역처럼 방치되어 있습니다.
# 가로등 설치해주세요.
# 동의초 옆 횡단보도 신호등이 생겼으면 좋겠습니다.
# 중곡역 놀이공간 점유하는 노인
# 제목 마트형 약국 안전한가요?
# 한강변 날벌레가 너무 많아요
# 주정차 위반 과태료 부과 자진납부는 현금만?
# 올림픽대교 북단 마트에서 설치한 천막 기둥때문에 보행이 불편함
# 광진구 중곡동 해오름 놀이터
# 집앞 하수도공사후 마무리 빨리해주세요
# 자양1 재정비 촉진구역 (구 KT) 새벽 공사
# 아차산배수지 테니스장 클럽 독점 관련의 건
# 광진구 중곡4동 해오름공원 놀이기구 문제입니다.
# 구의동 가로등 수리 요청 건
# 광진구체육센터 주변 자전거도로 철거 요청
# 제설요청
# 광진01 프라임아파트앞 정류장 전광판 고장
# 재활용 및 쓰레기
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from wordcloud import WordCloud
import time
import konlpy
from konlpy.tag import Okt
from konlpy.corpus import kolaw
import nltk

driver = webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver_win32\\chromedriver')
url ='https://gwangjin.eminwon.seoul.kr/emwp/gov/mogaha/ntis/web/emwp/cns/action/EmwpCnslWebAction.do?method=selectCnslWebPage&menu_id=EMWPCnslWebInqL&jndinm=EmwpCnslWebEJB&methodnm=selectCnslWebPage&context=NTIS'

try:
    driver.get(url)
    text = ""
    okt = Okt()
    for i in range(1, 11):
        title = driver.find_elements(By.CLASS_NAME, 'td-list')
        for j in title:
            text += j.text + " "
        
        if i < 10:
            page = driver.find_element(By.LINK_TEXT, str(i+1))
            page.click()
        time.sleep(2)

    token_ko = okt.nouns(j.text)
    stop_words = ["은", "는", "이", "가", "제", "의", "을", "를", "에서", "부터", 
              "와", "과", "및", "까지", "하여", "해서", "요", "우", "동", "조",
             "친", "로써", "함", "것", "월", "일", "그", "정", "수", "인", "장",
             "관", "위", "항", "때", "번", "기", "등", "및", "때문", "떼",
             "구", "후", "대한", "관련", "문의", "여부", "건", "내", "좀", "요청", "앞",
             "민원", "행정","부탁드립니다","광진구"]
    token_ko=[word for word in token_ko if word not in stop_words]
        
    wc = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf', background_color='white', width=800, height=600)
    wc.generate(text)
    wc.to_file('wordcloud.png')
except Exception as e:
    print(e)
finally:
    driver.close()
    driver.quit()
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_10076\4200488742.py:11: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver_win32\\chromedriver')

# %%
driver = webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver_win32\\chromedriver')
url ='https://gwangjin.eminwon.seoul.kr/emwp/gov/mogaha/ntis/web/emwp/cns/action/EmwpCnslWebAction.do?method=selectCnslWebPage&menu_id=EMWPCnslWebInqL&jndinm=EmwpCnslWebEJB&methodnm=selectCnslWebPage&context=NTIS'

try:
    driver.get(url)
    text = ""
    okt = Okt()
    for i in range(1, 11):
        title = driver.find_elements(By.CLASS_NAME, 'td-list')
        for j in title:
            text += j.text + " "
        
        if i < 10:
            page = driver.find_element(By.LINK_TEXT, str(i+1))
            page.click()
        time.sleep(2)

    token_ko = okt.nouns(text)
    stop_words = ["은", "는", "이", "가", "제", "의", "을", "를", "에서", "부터", 
              "와", "과", "및", "까지", "하여", "해서", "요", "우", "동", "조",
             "친", "로써", "함", "것", "월", "일", "그", "정", "수", "인", "장",
             "관", "위", "항", "때", "번", "기", "등", "및", "때문", "떼",
             "구", "후", "대한", "관련", "문의", "여부", "건", "내", "좀", "요청", "앞",
             "민원", "행정","부탁드립니다","광진구"]
    token_ko=[word for word in token_ko if word not in stop_words]
        
    wc = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf', background_color='white', width=800, height=600)
    wc.generate(' '.join(token_ko))
    wc.to_file('wordcloud.png')
except Exception as e:
    print(e)
finally:
    driver.close()
    driver.quit()
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_10076\2217627222.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver_win32\\chromedriver')

# %%
driver = webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver_win32\\chromedriver')
url ='https://gwangjin.eminwon.seoul.kr/emwp/gov/mogaha/ntis/web/emwp/cns/action/EmwpCnslWebAction.do?method=selectCnslWebPage&menu_id=EMWPCnslWebInqL&jndinm=EmwpCnslWebEJB&methodnm=selectCnslWebPage&context=NTIS'

try:
    driver.get(url)
    text = ""
    okt = Okt()
    for i in range(1, 21):
        title = driver.find_elements(By.CLASS_NAME, 'td-list')
        for j in title:
            text += j.text + " "
        i+=1
        if i % 10 ==1:
            page = driver.find_element(By.XPATH,'//*[@id="navigator"]/a[12]')
            page.click()
        else:
            page = driver.find_element(By.LINK_TEXT, str(i))
            page.click()
        time.sleep(2)

    token_ko = okt.nouns(text)
    stop_words = ["은", "는", "이", "가", "제", "의", "을", "를", "에서", "부터", 
              "와", "과", "및", "까지", "하여", "해서", "요", "우", "동", "조",
             "친", "로써", "함", "것", "월", "일", "그", "정", "수", "인", "장",
             "관", "위", "항", "때", "번", "기", "등", "및", "때문", "떼",
             "구", "후", "대한", "관련", "문의", "여부", "건", "내", "좀", "요청", "앞",
             "민원", "행정","부탁드립니다","광진구"]
    token_ko=[word for word in token_ko if word not in stop_words]
        
    wc = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf', background_color='white', width=800, height=600)
    wc.generate(' '.join(token_ko))
    wc.to_file('wordcloud.png')
except Exception as e:
    print(e)
finally:
    driver.close()
    driver.quit()
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_10076\1010241187.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver_win32\\chromedriver')
