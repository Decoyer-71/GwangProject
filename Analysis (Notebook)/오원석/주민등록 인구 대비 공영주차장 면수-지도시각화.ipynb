# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.font_manager as fm
font_name=fm.FontProperties(fname="C:\\Windows\\Fonts\\malgun.ttf ").get_name()
plt.rc("font", family=font_name)

import matplotlib as mlp
mlp.rcParams["axes.unicode_minus"]=False

# %% [markdown]
# ## 구별 공영주차장 면수 현황

# %%
park = pd.read_csv("C:/Users/user/ows4591/anaconda3/주차장(동별)(2016년+이후)_20230404180429.csv")
park.shape
# Out:
# (29, 3)

# %%
park = park.drop(0)
park
# Out:
#     동별(1)  동별(2)     2022
# 1   동별(1)  동별(2)       공영
# 2   동별(1)  동별(2)  면수 (면수)
# 3      합계     소계   177281
# 4      합계    종로구     5833
# 5      합계     중구     5399
# 6      합계    용산구     6375
# 7      합계    성동구     7056
# 8      합계    광진구     4856
# 9      합계   동대문구     5862
# 10     합계    중랑구    11179
# 11     합계    성북구     6447
# 12     합계    강북구     5286
# 13     합계    도봉구     5258
# 14     합계    노원구     3662
# 15     합계    은평구     5160
# 16     합계   서대문구     5899
# 17     합계    마포구     6828
# 18     합계    양천구     7454
# 19     합계    강서구     8895
# 20     합계    구로구     5149
# 21     합계    금천구     3715
# 22     합계   영등포구     9481
# 23     합계    동작구     3336
# 24     합계    관악구     6970
# 25     합계    서초구     7292
# 26     합계    강남구    13087
# 27     합계    송파구    16802
# 28     합계    강동구    10000

# %%
park = park.drop([1,2,3]).reset_index(drop=True)
park
# Out:
#    동별(1) 동별(2)   2022
# 0     합계   종로구   5833
# 1     합계    중구   5399
# 2     합계   용산구   6375
# 3     합계   성동구   7056
# 4     합계   광진구   4856
# 5     합계  동대문구   5862
# 6     합계   중랑구  11179
# 7     합계   성북구   6447
# 8     합계   강북구   5286
# 9     합계   도봉구   5258
# 10    합계   노원구   3662
# 11    합계   은평구   5160
# 12    합계  서대문구   5899
# 13    합계   마포구   6828
# 14    합계   양천구   7454
# 15    합계   강서구   8895
# 16    합계   구로구   5149
# 17    합계   금천구   3715
# 18    합계  영등포구   9481
# 19    합계   동작구   3336
# 20    합계   관악구   6970
# 21    합계   서초구   7292
# 22    합계   강남구  13087
# 23    합계   송파구  16802
# 24    합계   강동구  10000

# %%
park = park.drop("동별(1)", axis=1)
park
# Out:
#    동별(2)   2022
# 0    종로구   5833
# 1     중구   5399
# 2    용산구   6375
# 3    성동구   7056
# 4    광진구   4856
# 5   동대문구   5862
# 6    중랑구  11179
# 7    성북구   6447
# 8    강북구   5286
# 9    도봉구   5258
# 10   노원구   3662
# 11   은평구   5160
# 12  서대문구   5899
# 13   마포구   6828
# 14   양천구   7454
# 15   강서구   8895
# 16   구로구   5149
# 17   금천구   3715
# 18  영등포구   9481
# 19   동작구   3336
# 20   관악구   6970
# 21   서초구   7292
# 22   강남구  13087
# 23   송파구  16802
# 24   강동구  10000

# %%
park = park.rename(columns={'동별(2)': '구별', '2022': '면수'})
park
# Out:
#       구별     면수
# 0    종로구   5833
# 1     중구   5399
# 2    용산구   6375
# 3    성동구   7056
# 4    광진구   4856
# 5   동대문구   5862
# 6    중랑구  11179
# 7    성북구   6447
# 8    강북구   5286
# 9    도봉구   5258
# 10   노원구   3662
# 11   은평구   5160
# 12  서대문구   5899
# 13   마포구   6828
# 14   양천구   7454
# 15   강서구   8895
# 16   구로구   5149
# 17   금천구   3715
# 18  영등포구   9481
# 19   동작구   3336
# 20   관악구   6970
# 21   서초구   7292
# 22   강남구  13087
# 23   송파구  16802
# 24   강동구  10000

# %% [markdown]
# ## 구별 주민등록 인구

# %%
people = pd.read_csv("C:/Users/user/ows4591/anaconda3/주민등록인구(월별)_20230405092746.csv")
people.shape
# Out:
# (28, 5)

# %%
people
# Out:
#     동별(1)  동별(2) 2023. 02 2023. 02.1 2023. 02.2
# 0   동별(1)  동별(2)   합계 (명)     합계 (명)     합계 (명)
# 1   동별(1)  동별(2)       소계         남자         여자
# 2      합계     소계  9664666    4672790    4991876
# 3      합계    종로구   152167      72977      79190
# 4      합계     중구   130862      63390      67472
# 5      합계    용산구   232804     112817     119987
# 6      합계    성동구   287447     139319     148128
# 7      합계    광진구   350820     168004     182816
# 8      합계   동대문구   353869     172033     181836
# 9      합계    중랑구   390018     191231     198787
# 10     합계    성북구   441586     210974     230612
# 11     합계    강북구   297265     143739     153526
# 12     합계    도봉구   313137     151746     161391
# 13     합계    노원구   507104     243605     263499
# 14     합계    은평구   469489     223342     246147
# 15     합계   서대문구   320887     150867     170020
# 16     합계    마포구   376183     175195     200988
# 17     합계    양천구   443160     216468     226692
# 18     합계    강서구   574062     275161     298901
# 19     합계    구로구   418282     206350     211932
# 20     합계    금천구   242503     122554     119949
# 21     합계   영등포구   398657     196438     202219
# 22     합계    동작구   389322     187634     201688
# 23     합계    관악구   501998     251078     250920
# 24     합계    서초구   409220     195387     213833
# 25     합계    강남구   534971     255810     279161
# 26     합계    송파구   664553     319594     344959
# 27     합계    강동구   464300     227077     237223

# %%
people = people.drop([0,1,2]).reset_index(drop=True)
people
# Out:
#    동별(1) 동별(2) 2023. 02 2023. 02.1 2023. 02.2
# 0     합계   종로구   152167      72977      79190
# 1     합계    중구   130862      63390      67472
# 2     합계   용산구   232804     112817     119987
# 3     합계   성동구   287447     139319     148128
# 4     합계   광진구   350820     168004     182816
# 5     합계  동대문구   353869     172033     181836
# 6     합계   중랑구   390018     191231     198787
# 7     합계   성북구   441586     210974     230612
# 8     합계   강북구   297265     143739     153526
# 9     합계   도봉구   313137     151746     161391
# 10    합계   노원구   507104     243605     263499
# 11    합계   은평구   469489     223342     246147
# 12    합계  서대문구   320887     150867     170020
# 13    합계   마포구   376183     175195     200988
# 14    합계   양천구   443160     216468     226692
# 15    합계   강서구   574062     275161     298901
# 16    합계   구로구   418282     206350     211932
# 17    합계   금천구   242503     122554     119949
# 18    합계  영등포구   398657     196438     202219
# 19    합계   동작구   389322     187634     201688
# 20    합계   관악구   501998     251078     250920
# 21    합계   서초구   409220     195387     213833
# 22    합계   강남구   534971     255810     279161
# 23    합계   송파구   664553     319594     344959
# 24    합계   강동구   464300     227077     237223

# %%
people = people.drop("동별(1)", axis=1)
people
# Out:
#    동별(2) 2023. 02 2023. 02.1 2023. 02.2
# 0    종로구   152167      72977      79190
# 1     중구   130862      63390      67472
# 2    용산구   232804     112817     119987
# 3    성동구   287447     139319     148128
# 4    광진구   350820     168004     182816
# 5   동대문구   353869     172033     181836
# 6    중랑구   390018     191231     198787
# 7    성북구   441586     210974     230612
# 8    강북구   297265     143739     153526
# 9    도봉구   313137     151746     161391
# 10   노원구   507104     243605     263499
# 11   은평구   469489     223342     246147
# 12  서대문구   320887     150867     170020
# 13   마포구   376183     175195     200988
# 14   양천구   443160     216468     226692
# 15   강서구   574062     275161     298901
# 16   구로구   418282     206350     211932
# 17   금천구   242503     122554     119949
# 18  영등포구   398657     196438     202219
# 19   동작구   389322     187634     201688
# 20   관악구   501998     251078     250920
# 21   서초구   409220     195387     213833
# 22   강남구   534971     255810     279161
# 23   송파구   664553     319594     344959
# 24   강동구   464300     227077     237223

# %%
people = people.rename(columns={'동별(2)': '구별', '2023. 02': '합계(명)', '2023. 02.1':'남자(명)',
                               '2023. 02.2':'여자(명)'})
people
# Out:
#       구별   합계(명)   남자(명)   여자(명)
# 0    종로구  152167   72977   79190
# 1     중구  130862   63390   67472
# 2    용산구  232804  112817  119987
# 3    성동구  287447  139319  148128
# 4    광진구  350820  168004  182816
# 5   동대문구  353869  172033  181836
# 6    중랑구  390018  191231  198787
# 7    성북구  441586  210974  230612
# 8    강북구  297265  143739  153526
# 9    도봉구  313137  151746  161391
# 10   노원구  507104  243605  263499
# 11   은평구  469489  223342  246147
# 12  서대문구  320887  150867  170020
# 13   마포구  376183  175195  200988
# 14   양천구  443160  216468  226692
# 15   강서구  574062  275161  298901
# 16   구로구  418282  206350  211932
# 17   금천구  242503  122554  119949
# 18  영등포구  398657  196438  202219
# 19   동작구  389322  187634  201688
# 20   관악구  501998  251078  250920
# 21   서초구  409220  195387  213833
# 22   강남구  534971  255810  279161
# 23   송파구  664553  319594  344959
# 24   강동구  464300  227077  237223

# %%
result = pd.merge(park, people, on='구별')
result.set_index('구별',inplace=True)
result
# Out:
#          면수   합계(명)   남자(명)   여자(명)
# 구별
# 종로구    5833  152167   72977   79190
# 중구     5399  130862   63390   67472
# 용산구    6375  232804  112817  119987
# 성동구    7056  287447  139319  148128
# 광진구    4856  350820  168004  182816
# 동대문구   5862  353869  172033  181836
# 중랑구   11179  390018  191231  198787
# 성북구    6447  441586  210974  230612
# 강북구    5286  297265  143739  153526
# 도봉구    5258  313137  151746  161391
# 노원구    3662  507104  243605  263499
# 은평구    5160  469489  223342  246147
# 서대문구   5899  320887  150867  170020
# 마포구    6828  376183  175195  200988
# 양천구    7454  443160  216468  226692
# 강서구    8895  574062  275161  298901
# 구로구    5149  418282  206350  211932
# 금천구    3715  242503  122554  119949
# 영등포구   9481  398657  196438  202219
# 동작구    3336  389322  187634  201688
# 관악구    6970  501998  251078  250920
# 서초구    7292  409220  195387  213833
# 강남구   13087  534971  255810  279161
# 송파구   16802  664553  319594  344959
# 강동구   10000  464300  227077  237223

# %%
result=result.astype(float)
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 종로구 to 강동구
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   면수      25 non-null     float64
#  1   합계(명)   25 non-null     float64
#  2   남자(명)   25 non-null     float64
#  3   여자(명)   25 non-null     float64
# dtypes: float64(4)
# memory usage: 1000.0+ bytes

# %%
import folium
import json

# %%
import json
geo=json.load(open("C:/Users/user/ows4591/anaconda3/skorea_municipalities_geo_simple_seoul.json",
                  encoding="utf-8"))

import folium

map = folium.Map(location=[37.5000195, 127.0229206],zoom_start=11)


map.choropleth(geo_data=geo,  data=result["면수"], 
               key_on="feature.id",
               columns=[result["면수"]],
               fill_color="PuRd")
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_89f1022f9f37b31730bd111dd786f431 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_89f1022f9f37b31730bd111dd786f431&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_89f1022f9f37b31730bd111dd786f431 = L.map(
#                 &quot;map_89f1022f9f37b31730bd111dd786f431&quot;,
#                 {
#                     center: [37.5000195, 127.0229206],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0570ea9d3e65c5eacc08d8e01043680 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_89f1022f9f37b31730bd111dd786f431);
#
#
#             var choropleth_10f63aa6d1ef841618849e319e364117 = L.featureGroup(
#                 {}
#             ).addTo(map_89f1022f9f37b31730bd111dd786f431);
#
#
#         function geo_json_ed20f749c92f56c28f0d7eff503c440a_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc1a1\ud30c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;: case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc911\ub791\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_ed20f749c92f56c28f0d7eff503c440a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ed20f749c92f56c28f0d7eff503c440a = L.geoJson(null, {
#                 onEachFeature: geo_json_ed20f749c92f56c28f0d7eff503c440a_onEachFeature,
#
#                 style: geo_json_ed20f749c92f56c28f0d7eff503c440a_styler,
#         });
#
#         function geo_json_ed20f749c92f56c28f0d7eff503c440a_add (data) {
#             geo_json_ed20f749c92f56c28f0d7eff503c440a
#                 .addData(data)
#                 .addTo(choropleth_10f63aa6d1ef841618849e319e364117);
#         }
#             geo_json_ed20f749c92f56c28f0d7eff503c440a_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [127.11117085201238, 37.485708381512445], [127.0719146000724, 37.5022
