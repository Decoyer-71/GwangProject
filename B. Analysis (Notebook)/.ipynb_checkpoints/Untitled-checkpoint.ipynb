# %% [markdown]
# #### 생활안전도를 분석하여 광진구의 안전문제별 통계

# %%
import pandas as pd
import numpy as np

# %%
file= pd.read_excel('../A. Data/생활안전도(2011_2018)_20230403172537.xlsx', header=None, index_col=0)
file
# Out:
# C:\Users\acorn\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                 1      2      3      4      5      6      7      8      9   \
# 0
# 안전문제별(1)       서울시    서울시    서울시    서울시    서울시    서울시    서울시    서울시    서울시
# 안전문제별(1)     지역소분류  지역소분류  지역소분류  지역소분류  지역소분류  지역소분류  지역소분류  지역소분류  지역소분류
# 안전문제별(1)       종로구    종로구     중구     중구    용산구    용산구    성동구    성동구    광진구
# 안전문제별(1)      2011   2011   2011   2011   2011   2011   2011   2011   2011
# 안전문제별(1)        심각    비심각     심각    비심각     심각    비심각     심각    비심각     심각
# 길거리의 쓰레기방치    45.2   54.8   40.9   59.1   36.7   63.3   41.2   58.8   32.6
# 범죄 폭력         40.3   59.7   36.9   63.1   39.5   60.5   42.8   57.2   23.1
# 휴식공간 및 녹지부족   39.7   60.3   43.6   56.4     32     68   37.6   62.4   24.7
# ...
